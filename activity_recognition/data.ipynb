# %%
import pandas as pd
import glob


files = [f"data/{i}.csv" for i in range(501, 519)]

dfs = {fname: pd.read_csv(fname) for fname in files}

# Store only the columns for each file
file_columns = {fname: df.columns.tolist() for fname, df in dfs.items()}

# %%
file_columns
# Out:
# {'data/501.csv': ['timestamp',
#   'back_x',
#   'back_y',
#   'back_z',
#   'thigh_x',
#   'thigh_y',
#   'thigh_z',
#   'label'],
#  'data/502.csv': ['timestamp',
#   'back_x',
#   'back_y',
#   'back_z',
#   'thigh_x',
#   'thigh_y',
#   'thigh_z',
#   'label'],
#  'data/503.csv': ['timestamp',
#   'back_x',
#   'back_y',
#   'back_z',
#   'thigh_x',
#   'thigh_y',
#   'thigh_z',
#   'label'],
#  'data/504.csv': ['timestamp',
#   'back_x',
#   'back_y',
#   'back_z',
#   'thigh_x',
#   'thigh_y',
#   'thigh_z',
#   'label'],
#  'data/505.csv': ['timestamp',
#   'back_x',
#   'back_y',
#   'back_z',
#   'thigh_x',
#   'thigh_y',
#   'thigh_z',
#   'label'],
#  'data/506.csv': ['timestamp',
#   'back_x',
#   'back_y',
#   'back_z',
#   'thigh_x',
#   'thigh_y',
#   'thigh_z',
#   'label'],
#  'data/507.csv': ['timestamp',
#   'back_x',
#   'back_y',
#   'back_z',
#   'thigh_x',
#   'thigh_y',
#   'thigh_z',
#   'label'],
#  'data/508.csv': ['timestamp',
#   'back_x',
#   'back_y',
# ...

# %%
dfs["data/518.csv"]['label'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 dfs["data/519.csv"]['label'].value_counts()
#
# KeyError: 'data/519.csv'
